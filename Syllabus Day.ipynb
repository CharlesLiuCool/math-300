# %% [markdown]
# ### Syllabus Day
#
# Name: Charles Liu
# Description: First day, we downloaded Anaconda and GitHub Desktop. Then we learned about Jupyter Notebook.

# %%
(10 + 12)**6
# Out:
# 113379904

# %%
import numpy
numpy.mean([1,2,3,4,5])
